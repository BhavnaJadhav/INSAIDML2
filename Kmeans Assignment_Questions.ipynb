# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="110" /></center>
#
# # K-means Assignment

# %% [markdown]
# ## Customer Segmentation Dataset

# %% [markdown]
# __Context__
#
# - In today's competitive world, it is crucial to **understand customer bahaviour** and **categorise customers** based on their demography and buying behaviour.
#
# - This is broadly one aspect of **customer segmentation** that allows marketers to **better tailor** their **marketing efforts** to **various audience subsets** in terms of promotional, marketing and product development strategies.
#
# <br>
# __Objective__
#
# - This assignment demonstrates the concept of **segmentation** of a customer dataset from an **e-commerce** site using **k-means clustering** in python.
#
# - You will use the kmeans and the hierarchical clustering algorithms to derive the **optimum number of clusters** and **understand** the **underlying customer segments** based on the data provided.
#
# <br>
# __About the dataset__
#
# - The dataset consists of **Annual Income** (in **`$`**) and their **Annual Spend** (in **`$`**) on an e-commerce site for a period of one year.

# %% [markdown]
# ### Data Description
#
# | Column Name | Description |
# |:-----------:|:-----------:|
# | **INCOME** | Annual Income (in `$`). |
# | **SPEND** | Annual Spend (in `$`). |

# %% [markdown]
# ### Import the dataset

# %%
import pandas as pd
dataset= pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-3/master/Data/Assignment/CLV.csv')
dataset.head()

# %%
import matplotlib.pyplot as plt
% matplotlib inline
dataset.mean().plot(kind='bar')

# %% [markdown]
# ### Check the shape of the dataset

# %%
dataset.shape

# %% [markdown]
# ### Check the columns present in the dataset

# %%
dataset.columns

# %% [markdown]
# ### Check the descriptive statistics of the dataset

# %%
dataset.describe().transpose()

# %% [markdown]
# The mean annual income is `$`245000 and the mean annual spend is `$`149000.

# %% [markdown]
# ### Check the info of the dataset

# %%
dataset.info()

# %% [markdown]
# ### Q 1. Write a code to check the missing values present in the dataset.

# %%
def generate():
    return # Your variable to return
generate()

# %% [markdown]
# ### Q 2. Illustrate the distribution of the annual income and annual spend with a distplot.
#
#   - Plot **both** in a **single** chart.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def generate():
    # Your code here
generate()

# %% [markdown]
# ### Q 3. Illustrate the distribution of the annual income and annual spend with Violinplot.

# %%
def generate():
    # Your code here
generate()

# %% [markdown]
# ### Q 4. Draw scatter plot of Spend versus Income to understand the spread.
#
# - Use **color** as **black**
#
# - **Size** of marker as **100**

# %%
def generate():
    # Your code here
    return
generate()

# %% [markdown]
# __Plotting in 3D space__

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = Axes3D(fig)

X = np.array(list(zip(dataset['INCOME'], dataset['SPEND'])))
ax.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# ### Q 5 . Make a kmeans model to cluster the samples in 4 clusters.
#
# - Use the below parameters:
#
#   - `init` = **'k-means++'**
#
#   - `max_iter` = **300**
#
#   - `n_init` = **10**
#
#   - `random_state` = **0**
#
# - Return the **model**.
#
#
# - Also compute cluster centers and **predict** cluster index for each sample using `fit_predict` method
#
#   - Return this **variable** along with the model.

# %%
from sklearn.cluster import KMeans
def generate():
    # Your code here
    return # your variables here
km4, y_means = generate()

# %% [markdown]
# ### Q 6. Visualize the clusters using scatter plot (Spend Vs Income).
#
# - Take:
#
#   - Marker **size** as **50**
#
#   - **Colors** for clusters 1 to 4 as **purple**, **blue**, **green** & **cyan**
#
#   - **Labels** for various clusters as **Cluster1**, **Cluster2**, **Cluster3**, **Cluster4**.
#
# - For the cluster centres use:
#
#   - `marker` = **'s'**
#
#   - Marker **size** as **200**
#
#   - **Color** as **red**
#
#   - `alpha` blending value as **0.7**
#
#   - `label` as **'Centroids'**.
#
# - **Title** of the plot should be **'Customer segments'**
#
# - Set **"Annual income of customer"** as *label of x axis*
#
# - Set **"Annual spend from customer on site"** as *label of y axis*.

# %%
def generate():
    # your code here
    return 
generate()

# %% [markdown]
# __Interpretation of the 4 segments created__<br/>
#
# The plot shows the distribution of the 4 clusters.
#
# We could interpret them as the following customer segments:
#
# - **Cluster 1:** Customers with medium annual income and low annual spend
#
# - **Cluster 2:** Customers with high annual income and medium to high annual spend
#
# - **Cluster 3:** Customers with low annual income
#
# - **Cluster 4:** Customers with medium annual income but high annual spend
#
# <br>
# __Cluster 4__ straight away is one __potential customer segment__.
#
# However, Cluster 2 and 3 can be segmented further to arrive at a more specific target customer group.
#
# Let us now look at how the clusters are created when **k=6**:

# %% [markdown]
# ### Q 7. Make a kmeans model to cluster the samples in 6 clusters.
#
# - Use the below parameters:
#
#   - `init` = **'k-means++'**
#
#   - `max_iter` = **300**
#
#   - `n_init` = **10**
#
#   - `random_state` = **0**
#
# - Return the **model**.
#
#
# - Also compute cluster centers and **predict** cluster index for each sample using `fit_predict` method
#
#   - Return this **variable** along with the model.

# %%
def generate():
    # your code here
    return # your variables here
km6, y_means6 = generate()

# %% [markdown]
# ### Q 8. Visualize the clusters using scatter plot (Spend Vs Income).
#
# - Take:
#
#   - Marker **size** as **50**
#
#   - **Colors** for clusters 1 to 6 as **purple**, **blue**, **green**, **cyan**, **magenta** & **orange**
#
#   - **Labels** for various clusters as **Cluster1**, **Cluster2**, **Cluster3**, **Cluster4**, **Cluster5**, **Cluster6**.
#
# - For the cluster centres use:
#
#   - `marker` = **'s'**
#
#   - Marker **size** as **200**
#
#   - **Color** as **red**
#
#   - `alpha` blending value as **0.7**
#
#   - `label` as **'Centroids'**.
#
# - **Title** of the plot should be **'Customer segments'**
#
# - Set **"Annual income of customer"** as *label of x axis*
#
# - Set **"Annual spend from customer on site"** as *label of y axis*.

# %%
def generate():
    # your code here
    return 
generate()

# %% [markdown]
# __Interpretation of the 6 segments created__<br/>
#
# Setting the number of clusters to 6 seems to provide a more meaningful customer segmentation.
#
# - **Cluster 1:** Medium income, low annual spend
#
# - **Cluster 2:** Low income, low annual spend
#
# - **Cluster 3:** High income, high annual spend
#
# - **Cluster 4:** Low income, high annual spend
#
# - **Cluster 5:** Medium income, low annual spend
#
# - **Cluster 6:** Very high income, high annual spend
#
# <br>
# Thus it is evident that **6 clusters** provides a more **meaningful segmentation** of the customers.

# %% [markdown]
# ### Q 9. Use Elbow method to find the optimal number of cluster for this dataset.
#
# - Use the below parameters for the kmeans model.
#
#   - `init` = **'k-means++'**
#
#   - `max_iter` = **300**
#
#   - `n_init` = **10**
#
#   - `random_state` = **0**
#
# - **Plot** the graph between *Sum of squared distances of samples to their closest cluster center for number of clusters ranging between 1 to 11* **Versus** the *number of clusters*.

# %%
def generate():
    # your code here
    return
generate()

# %% [markdown]
# ### Q10. Plot a dendrogram to find the optimal number of clusters.
#
# -  Set  **"Hierarchical Clustering Dendrogram (truncated)"** as `title`
#
# - Set
#
#   - **"sample index or (cluster size)"** as  `xlabel`
#
#   - **"distance"** as `ylabel`.
#
# - For `linkage` use the **'ward'** method.
#
# - Also **show** only the **last 12 merged clusters** in the dendrogram.
#
# - Keep `leaf_font_size` as **12**.
#
# - In the plot also draw a line to select a **Distance Cut-Off** at **400** to determine the **Number of Clusters**.

# %%
import scipy.cluster.hierarchy as sch
def generate():
    # your code here
    return
generate()

# %% [markdown]
# - You can see the **best** choice for the *number of cluster* is **3**.

# %% [markdown]
# ### Q 11. Make a Hierarchical clustering model to cluster the samples in 3 clusters using Agglomerative Clustering object.
#
# - Use the below parameters:
#
#   - `affinity` = **'euclidean'**
#
#   - `compute_full_tree` = **'auto'**
#
#   - `connectivity` = **None**
#
#   - `linkage` = **'ward'**
#
#   - `memory` = **None**
#
#   - `pooling_func` = **'deprecated'**
#
# - Return the **model**.
#
# - Also compute cluster centers and **predict** cluster index for each sample using `fit_predict` method.
#
#   - Return this **variable** along with the model.

# %%
from sklearn.cluster import AgglomerativeClustering
def generate():
    # your code here
    return # your variables here
hc, y_hc = generate()

# %% [markdown]
# ### Q 12. Visulaize the clusters using scatter plot (Spend Vs Income).
#
# - Use the below parameters:
#
#   - Marker **size** as **50**
#
#   - **Color** for clusters 1 to 3 as **red**, **blue**, **green** respectively
#
#   - **Labels** for various clusters as **Cluster1**, **Cluster2**, **Cluster3**
#
#   - **Title** of the plot should be **'Clusters of customers'**
#
#   - Set **"Annual income of customer in $"** as *label of x axis*
#
#   - Set **"Annual spend in $"** as *label of y axis*.

# %%
def generate():
    # your code here
    return
generate()

# %% [markdown]
# __Interpretation of the 3 segments created__<br/>
#
# The plot shows the distribution of the 3 clusters.
#
# We could interpret them as the following customer segments:
#
# - **Cluster 1:** Customers with medium annual income and low to high annual spend
#
# - **Cluster 2:** Customers with low annual income and low to high annual spend
#
# - **Cluster 3:** Customers with high annual income and medium to high annual spend
