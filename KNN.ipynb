# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="110" /></center>
#
# # K - Nearest Neighbour

# %% [markdown]
# ## Table of Content
#
# 1. [Introduction to K - Nearest Neighbour](#section1)<br>
#     - 1.1 [When do we use KNN algorithm?](#section101)<br>
#         - 1.1.1 [KNN for Regression](#section102)<br>
#         - 1.1.2 [KNN for Classification](#section103)<br>
#     - 1.2 [How does the KNN algorithm work?](#section104)<br>
#     - 1.3 [Maths behind KNN slgorithm](#section105)<br>
#         - 1.3.1 [Explanation using Real life scenario](#section106)<br>
#     - 1.4 [How do we choose the factor K?](#section107)<br>
#     - 1.5 [Curse of Dimensionality](#section108)<br>
#     - 1.6 [KNN Disciplines](#section109)<br>
#     - 1.7 [Breaking it dowm - Pseudo Code of KNN](#section110)<br>
# 2. [Use Case - Glass Classification](#section2)<br>
# 3. [Data Loading](#section3)<br>
# 4. [Data Visualization](#section4)<br>
# 5. [Data Standardization](#section5)<br>
# 6. [Train test split](#section6)<br>
# 7. [Modelling and prediction](#section7)<br>
# 8. [Model Comparison](#section8)
# 9. [Implementing KNN Regressor on iris dataset](#section9)
# 10. [Conclusion](#section10)

# %% [markdown]
# <a id=section1></a>

# %% [markdown]
# ## 1. Introduction to K - Nearest neighbour

# %% [markdown]
# K-Nearest Neighbours is one of the most __basic yet essential classification algorithms__ in Machine Learning.
#
#  - It belongs to the __supervised learning__ domain and finds intense application in __pattern recognition__, __data mining__ and __intrusion detection__.
#
#  - It is widely disposable in real-life scenarios since it is non-parametric, meaning, it __does not make__ any __underlying assumptions__ about the distribution of data.
#
# __Supervised learning__, in the context of machine learning, is a type of system in which both __input__ and __desired output__ data are provided.
#
# - Input and output data are __labelled for classification__ to provide a learning basis for future data processing.
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download.png"/></center>

# %% [markdown]
# <a id=section101></a>

# %% [markdown]
# ## 1.1 When do we use KNN algorithm?

# %% [markdown]
# KNN can be used for both __classification and regression__ predictive problems.
#
# However, it is more widely used in classification problems in the industry.
#
# To evaluate any technique we generally look at __3 important aspects__:
#
# 1. *Ease to interpret output*
#
# 2. *Calculation Time*
#
# 3. *Predictive Power*
#
# Let us take a few examples to  place KNN on the scale of 3 :
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(1).png" /></center>
#
# <br>
# **Model comparison**:
#
# - KNN algorithm fairs across all parameters of considerations.
#
# - It is commonly used for its __ease of interpretation__ and __low calculation time__.
#
# - It is applicable for **smaller** datasets.

# %% [markdown]
# <a id=section102></a>
# ### 1.1.1 KNN for Regression
#
# When KNN is used for regression problems the _prediction is based on the __mean or the median__ of the K-most similar instances_.
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(2).png" /></center>

# %% [markdown]
# <a id=section103></a>
# ### 1.1.2 KNN for Classification
#
# When KNN is used for classification, the output can be calculated as the __class with the highest frequency__ from the __K-most similar instances__.
#
# Each instance in essence __votes for their class and the class with the most votes is taken as the prediction__.
#
# Class probabilities can be calculated as the normalized frequency of samples that belong to each class in the set of K most similar instances for a new data instance.
#
# <br>
#
# For example, in a binary classification problem (class is 0 or 1):
#
#   - $p(class=0) = count(class=0) / (count(class=0) + count(class=1))$
#
# <br>
#
# If you are using K and you have an even number of classes (e.g. 2) it is a good idea to choose a K value with an odd number to avoid a tie.
#
# - And the inverse, use an even number for K when you have an odd number of classes.
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(3).png" /></center>

# %% [markdown]
# <a id=section104></a>

# %% [markdown]
# ## 1.2 How does the KNN algorithm work?
# #### Also refer to the [**excel sheet**](https://github.com/insaid2018/Term-3/raw/master/Data/CaseStudy/KNN%20-%20Case%20Study.xlsx).

# %% [markdown]
# Let’s take a simple case to understand this algorithm.
#
# Following is a __spread of red circles (RC) and green squares (GS)__ :
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(4).png" /></center>
#
# <br>
# We intend to find out the __class of the blue star (BS)__ .
#
# - BS can either be RC or GS and nothing else.
#
# - The __“K”__ in KNN algorithm is the nearest neighbors we wish to take vote from.
#
# - __Let’s say K = 3__.
#
# - Hence, _we will now make a circle with BS as center just as big as to __enclose only three datapoints__ on the plane_.
#
# - Refer to following diagram for more details:
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(5).png" /></center>
#
# <br>
# - The _three closest points to BS_ is __all RC__.
#
# - Hence, with __good confidence level__ we can say that the _BS should belong to the class RC_.
#
# - Here, the __choice became very obvious__ as _all three votes from the closest neighbor went to RC_.
#
# - The choice of the parameter K is very crucial in this algorithm.

# %% [markdown]
# <a id=section105></a>

# %% [markdown]
# ## 1.3 Maths behind KNN algorithm

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(6).png" /></center>
#
# <br>
# - __Euclidian__ - The distance can be achieved as a __straight line__ between 2 points.
# - __Chebyshev__ - In this, __all adjacent 8 cells__ can be reached by __one unit__.
# - __Manhattan__ - The distance between two points is the __sum of the (absolute) differences of their coordinates__.
#
#   - E.g. it only costs __1 unit for a straight move__, but __2 if one wants to take a crossed move__.

# %% [markdown]
# ## We will see how distance is calculated between rows.

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/1.PNG" /></center>
#
# <br>

# %% [markdown]
# ### Bringing all the variables to a common scale.

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/2.PNG" /></center>
#
# <br>

# %% [markdown]
# ### Calculating the distance using Euclidian Distance Formula

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/4.jpg" /></center>
#
# <br>

# %% [markdown]
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/5.PNG" /></center>
#
# <br>

# %% [markdown]
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/6.PNG" /></center>
#
# <br>

# %% [markdown]
# <a id=section106></a>
# ### 1.3.1 Explanation using a Real Life Scenario
#
# In chess, the distance between squares on the chessboard for
#
# - __Rooks__ is measured in __Manhattan distance__
#
# - __Kings and queens__ use __Chebyshev distance__
#
# - __Bishops__ use the __Manhattan distance__ (between squares of the same color) on the chessboard __rotated 45 degrees__, i.e., with its diagonals as coordinate axes.
#
# - On an empty board:
#
#   - To reach from one square to another, __only kings require the number of moves equal to the distance__
#
#   - Rooks, queens and bishops require one or two moves (assuming that the move is possible at all in the bishop’s case).
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(7).png" /></center>

# %% [markdown]
# <a id=section107></a>

# %% [markdown]
# ## 1.4 How do we choose the factor K?

# %% [markdown]
# __KNN__ classifies a data point based on __how its neighbors are classified__.
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(8).png" /></center>
# <br>
#
# The class of _unknown data point was different at __k=3__ but __changed at k=7__, so which k should we choose?_
#
# KNN Algorithm is based on __feature similarity__: Choosing the right value of k is a process called __parameter tuning__, and is important for __better accuracy__.
#
# Although, the __best way__ to choose the __value of K__ are:

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(9).png" /></center>

# %% [markdown]
# <a id=section108></a>

# %% [markdown]
# ## 1.5 Curse of Dimensionality
#
# - KNN works well with a small number of input variables (p), but __struggles__ when the _number of inputs is very large_.
#
# - Each input variable can be considered a *dimension* of a **p-dimensional input** space.
#
#   - For example, if you had **two input variables** x1 and x2, the input space would be **2-dimensional**.
#
# - As the _number of dimensions increases the volume of the input space increases at an __exponential rate__._
#
# - In **high dimensions**, *points* that may be *similar* may have very **large distances**.
#
#   - All points will be **far away** from each other and our intuition for distances in simple 2 and 3-dimensional spaces breaks down.
#
#   - This might feel unintuitive at first, but this general problem is called the __Curse of Dimensionality__.
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-3/master/Images/download%20(10).png" /></center>

# %% [markdown]
# <a id=section109></a>

# %% [markdown]
# ## 1.6 KNN Disciplines
#
# As KNN have been around for a long time and has been very well studied.
#
# Different disciplines have different names for it.
#
# - __Instance-Based Learning__: The raw training instances are used to make predictions.
#
#   - As such KNN is often referred to as instance-based learning or a case-based learning (where __each training instance is a case from the problem domain__).
#
# - __Lazy Learning__: _No learning of the model is required_ and all of the __work happens__ at the time a __prediction is requested__.
#
#   - As such, KNN is often referred to as a __lazy learning algorithm__.
#
# - __Non-Parametric__: KNN makes _no assumptions about the __functional form of the problem__ being solved_.
#
#   - As such KNN is referred to as a __non-parametric__ machine learning algorithm.

# %% [markdown]
# #### What is Non-Parametric machine Learning Algorithm?
#
# - Algorithms that **do not make strong assumptions** about the form of the mapping function are called nonparametric machine learning algorithms.
#
# - By not making assumptions, they are **free to learn** any functional form from the training data.
#
#   > _Nonparametric methods are good when you have a lot of data and no prior knowledge, and when you don’t want to worry too much about choosing just the right features._
#
# <br>
# #### Benefits:
#
# 1. __Flexibility__: Capable of fitting a large number of functional forms.
#
# 2. __Power__: No assumptions (or weak assumptions) about the underlying function.
#
# 3. __Performance__: Can result in higher performance models for prediction.
#
# <br>
# #### Limitations:
#
# 1. __More data__: Require a lot more training data to estimate the mapping function.
#
# 2. __Slower__: A lot slower to train as they often have far more parameters to train.
#
# 3. __Overfitting__: More of a risk to overfit the training data and it is harder to explain why specific predictions are made.

# %% [markdown]
# <a id=section110></a>

# %% [markdown]
# ## 1.7 Breaking it Down – Pseudo Code of KNN

# %% [markdown]
# We can implement a KNN model by following the below steps:
#
# 1. **Load** the data.
#
# 2. Initialise the value of **k**.
#
# 3. For getting the predicted class, **iterate** from 1 to total number of training data points.
#
# 4. Calculate the **distance** between each test data and each row of training data.
#
#   - Here we will use **Euclidean distance** as our distance metric since it’s the most popular method.
#
#   - The other metrics that can be used are **Chebyshev**, **cosine**, etc.
#
# 5. Sort the calculated **distances** in **ascending order** based on distance values.
#
# 6. Get **top k** rows from the sorted array.
#
# 7. Get the **most frequent class** for *classification* and **mean or median** for *regression* of these rows.
#
# 8. Return the **predicted class**.

# %% [markdown]
# <a id=section2></a>

# %% [markdown]
# ## 2. Use Case - Glass Classification

# %% [markdown]
# - The study of classification of types of glass was motivated by __criminological investigation__.
#
# - At the scene of the crime, the glass left can be used as __evidence__, if it is correctly identified.
#
# - __Main ingredient of glass: $SiO_2$, other contents are also oxides, such as: $Na_2O$, $CaO$, $K_2O$__
#
# - Data set  has **9 key** properties.
#
#   - The first one is **optical** property.
#
#   - The rest 8 are **chemical oxide contents** of glass.
#
#   - So property 1 and property 2-9 have different dimensions.

# %% [markdown]
# ### Data Description:
#
# <br>
#
# | **Column Name** | **Description** |
# |:---------------:|:---------------:|
# | **RI** | Refractive index. |
# | **Na** | Sodium (weight percent in corresponding oxide). |
# | **Mg** | Magnesium (weight percent in corresponding oxide). |
# | **Al** | Aluminum (weight percent in corresponding oxide). |
# | **Si** | Silicon (weight percent in corresponding oxide). |
# | **K** | Potassium (weight percent in corresponding oxide). |
# | **Ca** | Calcium (weight percent in corresponding oxide). |
# | **Ba** | Barium (weight percent in corresponding oxide). |
# | **Fe** | Iron (weight percent in corresponding oxide). |
# | **Type** | Type of glass (**class attribute**) |

# %% [markdown]
# <br>
#
# - Glass class has **7** types, but type 4 is not present in this data set.
#
# <br>
#
# - **Glass Classes**:
#
#   1. *building_windows_float_processed*
#
#   2. *building_windows_non_float_processed*
#
#   3. *vehicle_windows_float_processed*
#
#   4. *vehicle_windows_non_float_processed* (none in this dataset)
#
#   5. *containers*
#
#   6. *tableware*
#
#   7. *headlamps*

# %% [markdown]
# <a id=section3></a>

# %% [markdown]
# ## 3. Data Loading
#
# - Dataset Source: https://archive.ics.uci.edu/ml/datasets/Glass+Identification
#
# - There are no missing values in the dataset as per the description in the source.

# %% [markdown]
# ### Import packages

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Import the dataset

# %%
glass = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-3/master/Data/CaseStudy/glass.csv")
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %% [markdown]
# #### Check the shape of dataset

# %%
glass.shape
# Out:
# (214, 10)

# %% [markdown]
# #### Check the columns present in the dataset

# %%
glass.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %% [markdown]
# #### Check the info of the dataset

# %%
glass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# **Observations**:
#
# - There are **214** samples and **10** features in the dataset.
#
# - **9** features are having `float` datatype, and **1** feature is having `int` datatype.

# %% [markdown]
# #### Check the descriptive statistics of the dataset

# %%
glass.describe()
# Out:
#                RI          Na          Mg  ...          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  ...  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533  ...    0.175047    0.057009    2.780374
# std      0.003037    0.816604    1.442408  ...    0.497219    0.097439    2.103739
# min      1.511150   10.730000    0.000000  ...    0.000000    0.000000    1.000000
# 25%      1.516523   12.907500    2.115000  ...    0.000000    0.000000    1.000000
# 50%      1.517680   13.300000    3.480000  ...    0.000000    0.000000    2.000000
# 75%      1.519157   13.825000    3.600000  ...    0.000000    0.100000    3.000000
# max      1.533930   17.380000    4.490000  ...    3.150000    0.510000    7.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# **Observations**:
#
# - The `RI` column has all the values lying between **1.51** and **1.53**

# %% [markdown]
# <a id=section4></a>

# %% [markdown]
# ## 4. Data Visualization

# %% [markdown]
# ### Count the number of observations on the basis of type and then create a barplot.

# %%
glass_type = glass['Type'].groupby(glass['Type']).count()
glass_type
# Out:
# Type
# 1    70
# 2    76
# 3    17
# 5    13
# 6     9
# 7    29
# Name: Type, dtype: int64

# %%
glass_type.plot(kind='bar')

# %% [markdown]
# **Observations**:
#
# - Here, we can see glass data is skewed, class 1 and 2 are in majority.

# %% [markdown]
# ### Creating a scatter plot by species.

# %%
sns.FacetGrid(glass, hue="Type", height=5).map(plt.scatter, "RI", "Na").add_legend()

# %% [markdown]
# ### Plotting Andrews Curve

# %%
# Andrews Curves involve using attributes of samples as coefficients for Fourier series and then plotting these
from pandas.plotting import andrews_curves
andrews_curves(glass, "Type")

# %% [markdown]
# **Observations**:
#
# - Andrews curves allow one to plot multivariate data as a large number of curves that are created using the attributes of samples as coefficients for Fourier series.
#
# - By coloring these curves differently for each class it is possible to visualize data clustering.
#
# - Curves belonging to samples of the same class will usually be closer together and form larger structures.

# %% [markdown]
# ### Plotting parallel coordinates

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(glass, "Type")

# %% [markdown]
# **Observations**:
#
# - Parallel coordinates plots each feature on a separate column & then draws lines connecting the features for each data sample.

# %% [markdown]
# ### Plotting radviz

# %%
from pandas.plotting import radviz
radviz(glass, "Type")

# %% [markdown]
# **Observations**:
#
# - Radviz puts each feature as a point on a 2D plane, and then simulates having each sample attached to those points through a spring weighted by the relative value for that feature.

# %% [markdown]
# <a id=section5></a>

# %% [markdown]
# ## 5. Data Standardization

# %% [markdown]
# ### Compute the skewness of the data

# %%
glass.skew()
# Out:
# RI      1.625431
# Na      0.454181
# Mg     -1.152559
# Al      0.907290
# Si     -0.730447
# K       6.551648
# Ca      2.047054
# Ba      3.416425
# Fe      1.754327
# Type    1.114915
# dtype: float64

# %% [markdown]
# ### Using StandardScaler to standardize the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
label = glass.pop('Type')

# %%
sc = StandardScaler()

sc.fit(glass)                                                                                   # fit the data to Standardscaler

glass_scale = sc.transform(glass)                                                               # transform the data

print('After standardizing our features, the first 5 rows of our data now look like this:\n')   # print the first 5 value after standardization
# Out:
# After standardizing our features, the first 5 rows of our data now look like this:

# %%
pd.DataFrame(glass_scale, columns=glass.columns).head()                                        # Put it to dataframe
# Out:
#          RI        Na        Mg  ...        Ca        Ba        Fe
# 0  0.872868  0.284953  1.254639  ... -0.145766 -0.352877 -0.586451
# 1 -0.249333  0.591817  0.636168  ... -0.793734 -0.352877 -0.586451
# 2 -0.721318  0.149933  0.601422  ... -0.828949 -0.352877 -0.586451
# 3 -0.232831 -0.242853  0.698710  ... -0.519052 -0.352877 -0.586451
# 4 -0.312045 -0.169205  0.650066  ... -0.624699 -0.352877 -0.586451
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Compute skewness after StandardScaler

# %%
pd.DataFrame(glass_scale).skew()
# Out:
# 0    1.625431
# 1    0.454181
# 2   -1.152559
# 3    0.907290
# 4   -0.730447
# 5    6.551648
# 6    2.047054
# 7    3.416425
# 8    1.754327
# dtype: float64

# %% [markdown]
# <a id=section6></a>

# %% [markdown]
# ## 6. Train-Test split

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test, label_train, label_test = train_test_split(glass_scale, label, test_size=0.3, random_state=42)

# %% [markdown]
# ### Check the shape of data_train and data_test

# %%
print('There are {} samples in the training set and {} samples in the test set'.format(
data_train.shape[0], data_test.shape[0]))
print()
# Out:
# There are 149 samples in the training set and 65 samples in the test set

# %% [markdown]
# <a id=section7></a>

# %% [markdown]
# ## 7. Modelling and prediction

# %% [markdown]
# ### 7.1.(a) Instantiate K nearest neighbour Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=7, p=2, metric='minkowski')

# %% [markdown]
# - Here, `n_neighbors` specify the number of nearest neighbors.

# %% [markdown]
# ### 7.1.(b) Fit the model

# %%
knn.fit(data_train, label_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %% [markdown]
# ### 7.1.(c) Use the model for prediction

# %%
y_preds = knn.predict(data_test)

# %% [markdown]
# ### 7.1.(d) Model evaluation using accuracy score

# %%
from sklearn.metrics import accuracy_score

# %%
knn_accuracy = accuracy_score(label_test, y_preds)
print('Accuracy score for the KNN model:', knn_accuracy)
# Out:
# Accuracy score for the KNN model: 0.6461538461538462

# %% [markdown]
# **Observations**:
#
# - Our **KNN** model achieves an accuracy of **64.6%** on the test set.

# %% [markdown]
# ### 7.2.(a) Instantiate Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logis = LogisticRegression()

# %% [markdown]
# ### 7.2.(b) Fit the model

# %%
logis.fit(data_train, label_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ### 7.2.(c) Use the model for prediction

# %%
y_pred = logis.predict(data_test)

# %% [markdown]
# ### 7.2.(d) Model Evaluation using Accuracy score

# %%
logit_accuracy = accuracy_score(label_test,y_pred)
print('Accuracy score for the Logistic model:', logit_accuracy)
# Out:
# Accuracy score for the Logistic model: 0.676923076923077

# %% [markdown]
# **Observations**:
#
# - Our **Logistic Regression** model achieves an accuracy of **64.6%** on the test set.

# %% [markdown]
# <a id=section8></a>

# %% [markdown]
# ## 8. Model Comparison using Accuracy Score

# %%
models = pd.DataFrame({'Model': ['Logistic Regression', 'kNN'], 'Accuracy_score': [logit_accuracy, knn_accuracy]})
models.sort_values(by='Accuracy_score', ascending=False)
# Out:
#                  Model  Accuracy_score
# 0  Logistic Regression        0.676923
# 1                  kNN        0.646154

# %% [markdown]
# **Observations**:
#
# - The Logistic Regression model slightly **outperforms** the KNN model.

# %% [markdown]
# ---

# %% [markdown]
# <a id=section9></a>

# %% [markdown]
# ## 9. Implementing KNN regressor using Iris Dataset

# %% [markdown]
# - This is perhaps the best known database to be found in the pattern recognition literature.
#
# - The data set contains **3** classes of **50** instances each, where each class refers to a type of iris plant.
#
# - One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# - **Predicted Attribute**: **Class** of iris plant.

# %%
# Importing the iris
iris = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-3/master/Data/CaseStudy/Iris.csv')

# %% [markdown]
# ### 9.1 Summarize the iris

# %%
# We can get a quick idea of how many instances (rows) and how many attributes (columns) the data contains with the shape property.
iris.shape
# Out:
# (150, 6)

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Let’s now take a look at the number of instances (rows) that belong to each class. We can view this as an absolute count.
iris.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ### 9.2 Dividing data into features and labels

# %% [markdown]
# **NOTE**:
#
# - As we can see iris contain six columns: `Id`, `SepalLengthCm`, `SepalWidthCm`, `PetalLengthCm`, `PetalWidthCm` and `Species`.
#
# - The actual features are described by columns 1-4.
#
# - Last column contains labels of samples.
#
# - Firstly we need to split data into two arrays: X (features) and y (labels).

# %%
feature_columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm','PetalWidthCm']
X = iris[feature_columns].values
y = iris['Species'].values

# Alternative way of selecting features and labels arrays:
# X = iris.iloc[:, 1:5].values
# y = iris.iloc[:, 5].values

# %% [markdown]
# ### 9.3 Label encoding

# %% [markdown]
# **NOTE**:
#
# - As we can see labels are categorical.
#
# - KNeighborsClassifier does not accept string labels.
#
# - We need to use `LabelEncoder` to transform them into numbers.
#
# - Iris-setosa correspond to 0, Iris-versicolor correspond to 1 and Iris-virginica correspond to 2.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %% [markdown]
# ### 9.4 Spliting iris into training set and test set

# %% [markdown]
# - Let's split iris into training set and test set, to check later on whether or not our regressor works correctly.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# - Lastly, because features values are in the same order of magnitude, there is no need for feature scaling.
#
# - Nevertheless in other circumstances it is extremly important to apply feature scaling before running classification algorithms.

# %% [markdown]
# ### 9.4 Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 9.4.1 Pairplot

# %% [markdown]
# - Pairplot is useful when you want to visualize the distribution of a variable or the relationship between multiple variables separately within subsets of your iris.

# %%
plt.figure()
sns.pairplot(iris.drop("Id", axis=1), hue="Species", height=3, markers=["o", "s", "D"])
plt.show()

# %% [markdown]
# #### 9.4.2. 3D visualization

# %% [markdown]
# - We can also try to  visualize high-dimensional irises in 3D using color, shape, size and other properties of 3D and 2D objects.
#
# - In this plot, we have used marks sizes to visualize fourth dimenssion which is Petal Width [cm].

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(20, 15))
ax = Axes3D(fig, elev=48, azim=134)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y,
           cmap=plt.cm.Set1, edgecolor='k', s = X[:, 3]*50)

for name, label in [('Virginica', 0), ('Setosa', 1), ('Versicolour', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean(),
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'),size=25)

ax.set_title("3D visualization", fontsize=40)
ax.set_xlabel("Sepal Length [cm]", fontsize=25)
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("Sepal Width [cm]", fontsize=25)
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("Petal Length [cm]", fontsize=25)
ax.w_zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# ### 9.5. Using KNN for Regression

# %% [markdown]
# #### 9.5.1 Making Predictions

# %%
# Loading libraries
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# - Instantiating Learning model (**k** = **3**).

# %%
regressor = KNeighborsRegressor(n_neighbors=3)

# %%
# Fitting the model
regressor.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### 9.5.2. Evaluating Predictions

# %%
from sklearn.metrics import mean_squared_error

# %%
cm = mean_squared_error(y_test, y_pred)
cm
# Out:
# 0.01851851851851852

# %% [markdown]
# **Observations**:
#
# - The MSE score for our **KNN** model is **0.018** on the test set.

# %%
cm = np.sqrt(mean_squared_error(y_test, y_pred))
cm
# Out:
# 0.13608276348795434

# %% [markdown]
# **Observations**:
#
# - The RMSE score for our **KNN** model is **0.13** on the test set.

# %% [markdown]
# #### 4.3. Using Cross-Validation for Parameter Tuning:

# %%
# creating list of K for KNN
k_list = list(range(1,50,2))
# creating list of cv scores
cv_scores = []

# perform 10-fold cross validation
for k in k_list:
    knn = KNeighborsRegressor(n_neighbors=k)
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='neg_mean_squared_error')
    cv_scores.append(scores.mean())

# %%
# changing to misclassification error
MSE = [1 - x for x in cv_scores]

plt.figure()
plt.figure(figsize=(15,10))
plt.title('The optimal number of neighbors', fontsize=20, fontweight='bold')
plt.xlabel('Number of Neighbors K', fontsize=15)
plt.ylabel('Misclassification Error', fontsize=15)
sns.set_style("whitegrid")
plt.plot(k_list, MSE)

plt.show()

# %%
# finding best k
best_k = k_list[MSE.index(min(MSE))]
print("The optimal number of neighbors is %d." % best_k)
# Out:
# The optimal number of neighbors is 9.

# %% [markdown]
# **Observations**:
#
# - The optimal number of **neighbors** for the KNN model on this dataset is **9**.

# %% [markdown]
# <a id=section10></a>

# %% [markdown]
# ### Conclusion
#
# - We first studied about the **KNN** algorithm.
#
#   - We learned about its **working**.
#
#   - Then we studied about the **Maths** behind the KNN algorithm.
#
#   - We also learned about the process of choosing the **K values** in the KNN algorithm.
#
# - After this, we started working on the business use case of **multiclass classfication** using KNN.
#
#   - We covered the process of **building** a KNN model using scikit-learn.
#
#   - Then how to use this model to make **predictions** on unseen data, and then **model evaluation**.
#
# - At last, we covered the case of using KNN for **regression** purposes on the **Iris** dataset.
#
#   - In this case, we also covered the process of selecting the **optimal** value of **K** in the KNN model.
